# %% [markdown]
# # Section 1: Prey Species in the California Drylands
#
# ## The Data
#
# This dataset contains information on arthropod prey species in California. It is also compiled with some environmental data, such as climate, elevation, and distance to nearest road. It is a synthesis of multiple datasets from sources such as the GBIF, USGS, and the U.S. Census, and it is currently being hosted by NCEAS. Prey data was acquired from Lortie et al. (2023)[ https://besjournals.onlinelibrary.wiley.com/doi/full/10.1002/2688-8319.12251]
#
# Link to the archive: https://knb.ecoinformatics.org/view/doi%3A10.5063%2FF1VM49RH
#
# Citations:
#
# *R. King, J. Braun, M. Westphal, and C. Lortie, “Compiled occurrence records for prey items of listed species found in California drylands with associated environmental data.” KNB Data Repository, 2023. doi: 10.5063/F1VM49RH. Available: https://knb.ecoinformatics.org/view/doi:10.5063/F1VM49RH. [Accessed: Aug. 26, 2024]*
#
# *C. J. Lortie, J. Braun, R. King, and M. Westphal, “The importance of open data describing prey item species lists for endangered species,” Ecological Solutions and Evidence, vol. 4, no. 2, p. e12251, Apr. 2023, doi: 10.1002/2688-8319.12251. Available: https://besjournals.onlinelibrary.wiley.com/doi/10.1002/2688-8319.12251. [Accessed: Aug. 26, 2024]*
#
# Date Accessed: 10/03/2025

# %% [markdown]
# ## Importing Meta and Prey Data

# %%
import pandas as pd

meta = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A3baf7289-bf90-4db3-ad11-58785c09b26e')
prey = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A23d42528-1048-45d4-85d1-7e13b666e744')

# %%
# Reviewing the metadata
meta
# Out:
#                         attribute  \
# 0                           class
# 1                           order
# 2                          family
# 3                           genus
# 4                         species
# 5                             lat
# 6                            long
# 7                       eventDate
# 8                             day
# 9                           month
# 10                           year
# 11                institutionCode
# 12  coordinateUncertaintyInMeters
# 13                  basisOfRecord
# 14                individualCount
# 15                     datasetKey
# 16                           bio1
# 17                          bio10
# 18                          bio11
# 19                          bio12
# 20                          bio13
# 21                          bio14
# 22                          bio15
# 23                          bio16
# 24                          bio17
# 25                          bio18
# ...

# %%
# Checking type of dataset
prey.dtypes

# prey contains a mix of strings and floats (numerical)
# Out:
# class                             object
# order                             object
# family                            object
# genus                             object
# species                           object
# lat                              float64
# long                             float64
# eventDate                         object
# day                              float64
# month                            float64
# year                               int64
# institutionCode                   object
# coordinateUncertaintyInMeters    float64
# basisOfRecord                     object
# individualCount                  float64
# datasetKey                        object
# ID                                 int64
# bio1                             float64
# bio10                            float64
# bio11                            float64
# bio12                            float64
# bio13                            float64
# bio14                            float64
# ...

# %% [markdown]
# ## Data Review

# %%
# Previewing prey data
prey
# Out:
#                class        order           family          genus  \
# 0            Insecta      Odonata     Libellulidae      Sympetrum
# 1       Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2            Insecta  Hymenoptera           Apidae         Bombus
# 3            Insecta  Hymenoptera           Apidae           Apis
# 4            Insecta    Hemiptera        Lygaeidae     Oncopeltus
# ...              ...          ...              ...            ...
# 111151       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111152       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111153       Insecta  Hymenoptera       Formicidae     Liometopum
# 111154       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111155       Insecta  Lepidoptera      Nymphalidae        Vanessa
#
#                           species        lat        long  \
# 0             Sympetrum corruptum  37.173971 -121.856329
# ...

# %%
# Adjusting settings to be able to see ALL columns and none are ommitted 
pd.set_option("display.max.columns", None)
prey
# Out:
#                class        order           family          genus  \
# 0            Insecta      Odonata     Libellulidae      Sympetrum
# 1       Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2            Insecta  Hymenoptera           Apidae         Bombus
# 3            Insecta  Hymenoptera           Apidae           Apis
# 4            Insecta    Hemiptera        Lygaeidae     Oncopeltus
# ...              ...          ...              ...            ...
# 111151       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111152       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111153       Insecta  Hymenoptera       Formicidae     Liometopum
# 111154       Insecta  Hymenoptera       Formicidae   Pogonomyrmex
# 111155       Insecta  Lepidoptera      Nymphalidae        Vanessa
#
#                           species        lat        long  \
# 0             Sympetrum corruptum  37.173971 -121.856329
# ...

# %% [markdown]
# ## Preliminary Exploration

# %%
# head()
# Shows first 5 observations of data set
prey.head()
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  year institutionCode  coordinateUncertaintyInMeters  \
# 0    9.0  2020     iNaturalist                          684.0
# ...

# %%
# tail()
# Shows last 5
prey.tail()
# Out:
#           class        order       family         genus  \
# 111151  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111152  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111153  Insecta  Hymenoptera   Formicidae    Liometopum
# 111154  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111155  Insecta  Lepidoptera  Nymphalidae       Vanessa
#
#                           species        lat        long  \
# 111151  Pogonomyrmex californicus  33.660853 -115.721380
# 111152  Pogonomyrmex californicus  35.933333 -116.716667
# 111153     Liometopum occidentale  34.156833 -118.726833
# 111154  Pogonomyrmex californicus  32.989167 -116.658500
# 111155             Vanessa cardui  36.251400 -117.731400
#
#                    eventDate   day  month  year institutionCode  \
# 111151  1980-04-10T00:00:00Z  10.0    4.0  1980             MCZ
# 111152  1998-03-26T00:00:00Z  26.0    3.0  1998             MCZ
# 111153  2010-05-21T00:00:00Z  21.0    5.0  2010             MCZ
# ...

# %%
# info()
#Shows column names with non-null count and dtypes
prey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111156 entries, 0 to 111155
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   class                          111156 non-null  object
#  1   order                          111054 non-null  object
#  2   family                         111156 non-null  object
#  3   genus                          111156 non-null  object
#  4   species                        111156 non-null  object
#  5   lat                            111156 non-null  float64
#  6   long                           111156 non-null  float64
#  7   eventDate                      111156 non-null  object
#  8   day                            110998 non-null  float64
#  9   month                          111127 non-null  float64
#  10  year                           111156 non-null  int64
#  11  institutionCode                110414 non-null  object
# ...

# %%
# nunique()
# Shows the number of unique values in each column
prey.nunique()
# Out:
# class                                 4
# order                                18
# family                               63
# genus                                92
# species                              97
# lat                               91909
# long                              91965
# eventDate                        102140
# day                                  31
# month                                12
# year                                 77
# institutionCode                      77
# coordinateUncertaintyInMeters      4450
# basisOfRecord                         4
# individualCount                      42
# datasetKey                           88
# ID                               111156
# bio1                              11778
# bio10                             11981
# bio11                             11803
# bio12                             12117
# bio13                             12020
# bio14                              4586
# ...

# %%
# shape
# Returns the "shape" of the dataframe in (rows, columns) format
prey.shape
# Out:
# (111156, 40)

# %%
# columns()
# Returns the columns names of the dataset
prey.columns
# Out:
# Index(['class', 'order', 'family', 'genus', 'species', 'lat', 'long',
#        'eventDate', 'day', 'month', 'year', 'institutionCode',
#        'coordinateUncertaintyInMeters', 'basisOfRecord', 'individualCount',
#        'datasetKey', 'ID', 'bio1', 'bio10', 'bio11', 'bio12', 'bio13', 'bio14',
#        'bio15', 'bio16', 'bio17', 'bio18', 'bio19', 'bio2', 'bio3', 'bio4',
#        'bio5', 'bio6', 'bio7', 'bio8', 'bio9', 'dist', 'dem90_hf', 'lc_class',
#        'ndvi'],
#       dtype='object')

# %%
# dtypes()
# Shows the data type stored in each column of the dataframe
prey.dtypes
# Out:
# class                             object
# order                             object
# family                            object
# genus                             object
# species                           object
# lat                              float64
# long                             float64
# eventDate                         object
# day                              float64
# month                            float64
# year                               int64
# institutionCode                   object
# coordinateUncertaintyInMeters    float64
# basisOfRecord                     object
# individualCount                  float64
# datasetKey                        object
# ID                                 int64
# bio1                             float64
# bio10                            float64
# bio11                            float64
# bio12                            float64
# bio13                            float64
# bio14                            float64
# ...

# %% [markdown]
# ## Updating Column Names

# %%
# Using rename() to change two columns names
prey = prey.rename(columns = {"institutionCode":"institution_code", "datasetKey":"dataset_key"})

# %% [markdown]
# ## Subsetting

# %%
preserved_prey = prey[prey["basisOfRecord"] == "PRESERVED_SPECIMEN"]

# %%
preserved_prey
# Out:
#           class        order       family         genus  \
# 1679    Insecta  Hymenoptera       Apidae          Apis
# 1680    Insecta  Hymenoptera     Xyelidae         Xyela
# 1681    Insecta  Hymenoptera       Apidae          Apis
# 1682    Insecta  Hymenoptera       Apidae          Apis
# 1683    Insecta  Hymenoptera     Xyelidae         Xyela
# ...         ...          ...          ...           ...
# 111151  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111152  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111153  Insecta  Hymenoptera   Formicidae    Liometopum
# 111154  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111155  Insecta  Lepidoptera  Nymphalidae       Vanessa
#
#                           species        lat        long  \
# 1679               Apis mellifera  34.340000 -119.410004
# 1680                Xyela concava  38.759998 -119.660004
# 1681               Apis mellifera  34.290001 -119.230003
# 1682               Apis mellifera  32.689999 -117.180000
# ...

# %%
spec_years = prey[prey["year"].between(1992, 2000)]

# spec_years = prey[(prey['years']>=1992) & (prey['years']<=2000)]

# %%
spec_years
# Out:
#           class        order          family         genus  \
# 1700    Insecta   Coleoptera   Tenebrionidae       Eleodes
# 1717    Insecta  Hymenoptera      Formicidae  Pogonomyrmex
# 1721    Insecta  Hymenoptera      Formicidae  Pogonomyrmex
# 1732    Insecta   Orthoptera       Acrididae    Melanoplus
# 1734    Insecta   Orthoptera       Acrididae  Schistocerca
# ...         ...          ...             ...           ...
# 109844  Insecta      Odonata  Coenagrionidae      Ischnura
# 109845  Insecta  Hymenoptera          Apidae        Bombus
# 111149  Insecta  Hymenoptera      Formicidae  Pogonomyrmex
# 111152  Insecta  Hymenoptera      Formicidae  Pogonomyrmex
# 111155  Insecta  Lepidoptera     Nymphalidae       Vanessa
#
#                           species        lat        long  \
# 1700           Eleodes acuticauda  34.421123 -118.501387
# 1717    Pogonomyrmex californicus  34.467772 -116.202715
# 1721    Pogonomyrmex californicus  36.248500 -117.991028
# ...

# %%
prey_sub = prey[ ['species', 'eventDate']]

# %%
prey_sub
# Out:
#                           species             eventDate
# 0             Sympetrum corruptum  2020-09-29T08:24:00Z
# 1           Armadillidium vulgare  2021-12-04T14:49:59Z
# 2             Bombus vosnesenskii  2021-06-18T08:52:00Z
# 3                  Apis mellifera  2016-04-17T09:28:00Z
# 4            Oncopeltus fasciatus  2019-04-06T18:44:31Z
# ...                           ...                   ...
# 111151  Pogonomyrmex californicus  1980-04-10T00:00:00Z
# 111152  Pogonomyrmex californicus  1998-03-26T00:00:00Z
# 111153     Liometopum occidentale  2010-05-21T00:00:00Z
# 111154  Pogonomyrmex californicus  2010-05-25T00:00:00Z
# 111155             Vanessa cardui  1992-09-02T00:00:00Z
#
# [111156 rows x 2 columns]

# %%
prey[(prey['lat'] > 37) & (prey['lat']<39)]
# Out:
#                class        order           family          genus  \
# 0            Insecta      Odonata     Libellulidae      Sympetrum
# 1       Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 5            Insecta      Diptera        Syrphidae     Allograpta
# 9            Insecta  Lepidoptera      Nymphalidae        Vanessa
# 10           Insecta  Lepidoptera       Sphingidae          Hyles
# ...              ...          ...              ...            ...
# 111125       Insecta  Hymenoptera           Apidae         Bombus
# 111128  Malacostraca      Isopoda        Oniscidae        Oniscus
# 111138       Insecta      Diptera        Syrphidae      Toxomerus
# 111140       Insecta  Hymenoptera           Apidae           Apis
# 111145       Insecta   Coleoptera    Coccinellidae     Hippodamia
#
#                       species        lat        long             eventDate  \
# 0         Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z
# ...
